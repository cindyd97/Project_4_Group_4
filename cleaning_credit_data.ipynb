# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

# %%
# Import our input datasets
credit_url = 'https://raw.githubusercontent.com/cindyd97/Project_4_Group_4/main/Resources/Credit_data.csv'
credit_df = pd.read_csv(credit_url)
credit_df.head()
# Out:
#         ID Customer_ID      Month             Name  Age          SSN  \
# 0   0x160a   CUS_0xd40  September    Aaron Maashoh   23  821-00-0265
# 1   0x160b   CUS_0xd40    October    Aaron Maashoh   24  821-00-0265
# 2   0x160c   CUS_0xd40   November    Aaron Maashoh   24  821-00-0265
# 3   0x160d   CUS_0xd40   December    Aaron Maashoh  24_  821-00-0265
# 4   0x1616  CUS_0x21b1  September  Rick Rothackerj   28  004-07-5839
# ..     ...         ...        ...              ...  ...          ...
# 95  0x1721  CUS_0x5b48   December         McBrideq   32  706-95-0150
# 96  0x172a  CUS_0xa5f9  September            Rickt   34  189-09-5267
# 97  0x172b  CUS_0xa5f9    October            Rickt   35  189-09-5267
# 98  0x172c  CUS_0xa5f9   November            Rickt   35  189-09-5267
# 99  0x172d  CUS_0xa5f9   December            Rickt   35  189-09-5267
#
#    Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0   Scientist      19114.12            1824.843333                  3  ...
# 1   Scientist      19114.12            1824.843333                  3  ...
# 2   Scientist      19114.12            1824.843333                  3  ...
# 3   Scientist      19114.12                    NaN                  3  ...
# 4     _______      34847.84            3037.986667                  2  ...
# ..        ...           ...                    ...                ...  ...
# 95     Lawyer     12600.445             782.037083                  5  ...
# 96   Mechanic      57983.12            4720.926667                  9  ...
# 97   Mechanic      57983.12            4720.926667                  9  ...
# 98   Mechanic      57983.12                    NaN                  9  ...
# 99   Mechanic      57983.12            4720.926667                  9  ...
#
#     Num_Credit_Inquiries  Credit_Mix Outstanding_Debt  \
# 0                 2022.0        Good           809.98
# 1                    4.0        Good           809.98
# 2                    4.0        Good           809.98
# 3                    4.0        Good           809.98
# 4                    5.0        Good           605.03
# ..                   ...         ...              ...
# 95                  11.0    Standard            569.8
# 96                  17.0         Bad          3532.83
# 97                  17.0           _          3532.83
# 98                  17.0         Bad          3532.83
# 99                  17.0         Bad          3532.83
#
#    Credit_Utilization_Ratio      Credit_History_Age Payment_of_Min_Amount  \
# 0                 35.030402   22 Years and 9 Months                    No
# 1                 33.053114  22 Years and 10 Months                    No
# 2                 33.811894                     NaN                    No
# 3                 32.430559   23 Years and 0 Months                    No
# 4                 25.926822   27 Years and 3 Months                    No
# ..                      ...                     ...                   ...
# 95                30.542582   13 Years and 2 Months                    NM
# 96                36.791421  12 Years and 10 Months                   Yes
# 97                26.583209  12 Years and 11 Months                   Yes
# 98                35.316385   13 Years and 0 Months                   Yes
# 99                35.581888   13 Years and 1 Months                   Yes
#
#    Total_EMI_per_month  Amount_invested_monthly  \
# 0            49.574949       236.64268203272135
# 1            49.574949       21.465380264657146
# 2            49.574949       148.23393788500925
# 3            49.574949        39.08251089460281
# 4            18.816215       39.684018417945296
# ..                 ...                      ...
# 95           26.060348       19.600997331776377
# 96          200.432613        172.3887516003397
# 97          200.432613        527.1452187488069
# 98          200.432613       191.04338258925824
# 99          200.432613       304.19540618394814
#
#                    Payment_Behaviour     Monthly_Balance
# 0     Low_spent_Small_value_payments  186.26670208571772
# 1   High_spent_Medium_value_payments  361.44400385378196
# 2    Low_spent_Medium_value_payments  264.67544623342997
# 3   High_spent_Medium_value_payments  343.82687322383634
# 4    High_spent_Large_value_payments   485.2984336755923
# ..                               ...                 ...
# 95  High_spent_Medium_value_payments    282.542363472351
# 96   High_spent_Small_value_payments  359.27130167162017
# 97    Low_spent_Small_value_payments   34.51483452315301
# 98  High_spent_Medium_value_payments   330.6166706827016
# 99    Low_spent_Small_value_payments   257.4646470880118
#
# [100 rows x 27 columns]

# %%
# Check the data types for each column
credit_df.dtypes
# Out:
# ID                           object
# Customer_ID                  object
# Month                        object
# Name                         object
# Age                          object
# SSN                          object
# Occupation                   object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                  object
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit         object
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# Monthly_Balance              object
# dtype: object

# %%
# Check the null values in the data set
credit_df.isnull().sum()

# %%
# Drop unnecessary columns (columns that are not needed for our features)
credit_df = credit_df.drop(['ID','Customer_ID','Name','SSN'], axis=1)

# %%
# Convert columns that are meant to be numeric to an integer
columns_to_convert = ['Age','Annual_Income','Num_of_Loan','Num_of_Delayed_Payment','Changed_Credit_Limit','Num_Credit_Inquiries','Outstanding_Debt',
                      'Total_EMI_per_month','Amount_invested_monthly','Monthly_Balance']
credit_df[columns_to_convert] = credit_df[columns_to_convert].apply(pd.to_numeric, errors='coerce').astype('float64')

# %%
# Create a function that would convert the strings in 'Credit_History_Age' column to a float. (This column is a string that describes the amount of years and months
# the customer's credit age is)
def convert_to_float(years_months):
    if pd.isna(years_months):
        return 0.0
    parts = years_months.split()
    years = int(parts[0])
    months = int(parts[3])
    return round(years + (months / 12), 2)
# Apply function to convert
credit_df['Credit_History_Age'] = credit_df['Credit_History_Age'].apply(convert_to_float)
# Out:
#        Month   Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0  September  23.0  Scientist       19114.12            1824.843333
# 1    October  24.0  Scientist       19114.12            1824.843333
# 2   November  24.0  Scientist       19114.12            1824.843333
# 4  September  28.0    _______       34847.84            3037.986667
# 5    October  28.0    Teacher       34847.84            3037.986667
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                  3                4              3          4.0
# 1                  3                4              3          4.0
# 2                  3                4              3          4.0
# 4                  2                4              6          1.0
# 5                  2                4              6          1.0
#
#                                         Type_of_Loan  ...  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...  ...
# 1  Auto Loan, Credit-Builder Loan, Personal Loan,...  ...
# 2  Auto Loan, Credit-Builder Loan, Personal Loan,...  ...
# 4                                Credit-Builder Loan  ...
# 5                                Credit-Builder Loan  ...
#
#    Num_Credit_Inquiries  Credit_Mix  Outstanding_Debt  \
# 0                2022.0        Good            809.98
# 1                   4.0        Good            809.98
# 2                   4.0        Good            809.98
# 4                   5.0        Good            605.03
# 5                   5.0        Good            605.03
#
#    Credit_Utilization_Ratio Credit_History_Age  Payment_of_Min_Amount  \
# 0                 35.030402              22.75                     No
# 1                 33.053114              22.83                     No
# 2                 33.811894               0.00                     No
# 4                 25.926822              27.25                     No
# 5                 30.116600              27.33                     No
#
#    Total_EMI_per_month  Amount_invested_monthly  \
# 0            49.574949               236.642682
# 1            49.574949                21.465380
# 2            49.574949               148.233938
# 4            18.816215                39.684018
# 5            18.816215               251.627369
#
#                   Payment_Behaviour  Monthly_Balance
# 0    Low_spent_Small_value_payments       186.266702
# 1  High_spent_Medium_value_payments       361.444004
# 2   Low_spent_Medium_value_payments       264.675446
# 4   High_spent_Large_value_payments       485.298434
# 5    Low_spent_Large_value_payments       303.355083
#
# [5 rows x 23 columns]

# %%
# Logically, the null values in the 'Age' column should not be changed to 0. Remove the rows with null values in this column
credit_df = credit_df.dropna(subset=['Age'])

# %%
# Check the null values in the data set
credit_df.isnull().sum()
# Out:
# Month                          0
# Age                            0
# Occupation                     0
# Annual_Income               3334
# Monthly_Inhand_Salary       7122
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                 2312
# Type_of_Loan                5416
# Delay_from_due_date            0
# Num_of_Delayed_Payment      4678
# Changed_Credit_Limit        1004
# Num_Credit_Inquiries         980
# Credit_Mix                     0
# Outstanding_Debt             466
# Credit_Utilization_Ratio       0
# Credit_History_Age             0
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly     4229
# Payment_Behaviour              0
# Monthly_Balance              534
# dtype: int64

# %%
# For all null values in 'Type_of_Loan column', update the string to say 'Not Specified'
credit_df['Type_of_Loan'] = credit_df['Type_of_Loan'].fillna('Not Specified')

# %%
# Check the null values in the data set
credit_df.isnull().sum()
# Out:
# Month                          0
# Age                            0
# Occupation                     0
# Annual_Income               3334
# Monthly_Inhand_Salary       7122
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                 2312
# Type_of_Loan                   0
# Delay_from_due_date            0
# Num_of_Delayed_Payment      4678
# Changed_Credit_Limit        1004
# Num_Credit_Inquiries         980
# Credit_Mix                     0
# Outstanding_Debt             466
# Credit_Utilization_Ratio       0
# Credit_History_Age             0
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly     4229
# Payment_Behaviour              0
# Monthly_Balance              534
# dtype: int64

# %%
# The remaining columns with null values may be updated with the number 0
columns_to_fill = ['Annual_Income', 'Monthly_Inhand_Salary', 'Num_of_Loan','Num_of_Delayed_Payment','Changed_Credit_Limit','Num_Credit_Inquiries','Outstanding_Debt','Amount_invested_monthly','Monthly_Balance']
credit_df[columns_to_fill] = credit_df[columns_to_fill].fillna(0)

# %%
# Check the null values in the data set
credit_df.isnull().sum()
# Out:
# Month                       0
# Age                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# dtype: int64

# %%
# Download the cleaned data set
credit_df.to_csv('clean_credit_data.csv', index=False)
from google.colab import files
files.download("clean_credit_data.csv")
